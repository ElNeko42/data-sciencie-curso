# %% [markdown]
# ## Ejercicio pandas 2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Ejercicio 0:
# - Carga el archivo **`titanic.csv`** y guardalo en la variable **`df`**

# %%
df = pd.read_csv("Data/titanic.csv")

# %% [markdown]
# ### Ejercicio 1:
# - Muestra la información del DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Name         891 non-null    object
#  2   Sex          891 non-null    object
#  3   Age          714 non-null    float64
#  4   Survived     891 non-null    int64
#  5   Pclass       891 non-null    int64
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 55.8+ KB

# %% [markdown]
# ### Ejercicio 2:
# - Cambia las columnas del tipo **`"object"`** a tipo **`"category"`**.

# %%
cat_cols = df.select_dtypes("object").columns

# %%
cat_cols = ["Name", "Sex", "Ticket"]

# %%
df[cat_cols] = df[cat_cols].astype("category")

# %% [markdown]
# ### Ejercicio 3:
# - Obten un DataFrame solo con hombres.

# %%
df[df['Sex'] == "male"]
# Out:
#      PassengerId                            Name   Sex   Age  Survived  \
# 0              1         Braund, Mr. Owen Harris  male  22.0         0
# 4              5        Allen, Mr. William Henry  male  35.0         0
# 5              6                Moran, Mr. James  male   NaN         0
# 6              7         McCarthy, Mr. Timothy J  male  54.0         0
# 7              8  Palsson, Master. Gosta Leonard  male   2.0         0
# ..           ...                             ...   ...   ...       ...
# 883          884   Banfield, Mr. Frederick James  male  28.0         0
# 884          885          Sutehall, Mr. Henry Jr  male  25.0         0
# 886          887           Montvila, Rev. Juozas  male  27.0         0
# 889          890           Behr, Mr. Karl Howell  male  26.0         1
# 890          891             Dooley, Mr. Patrick  male  32.0         0
#
#      Pclass            Ticket     Fare
# 0         3         A/5 21171   7.2500
# 4         3            373450   8.0500
# 5         3            330877   8.4583
# 6         1             17463  51.8625
# 7         3            349909  21.0750
# ..      ...               ...      ...
# 883       2  C.A./SOTON 34068  10.5000
# 884       3   SOTON/OQ 392076   7.0500
# 886       2            211536  13.0000
# 889       1            111369  30.0000
# 890       3            370376   7.7500
#
# [577 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 4:
# - Obten un DataFrame con los pasajeros de clase 1 y 2.

# %%
df[ df['Pclass'].isin([1,2]) ]
# Out:
#      PassengerId                                               Name     Sex  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 6              7                            McCarthy, Mr. Timothy J    male
# 9             10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 11            12                           Bonnell, Miss. Elizabeth  female
# ..           ...                                                ...     ...
# 880          881       Shelley, Mrs. William (Imanita Parrish Hall)  female
# 883          884                      Banfield, Mr. Frederick James    male
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 889          890                              Behr, Mr. Karl Howell    male
#
#       Age  Survived  Pclass            Ticket     Fare
# 1    38.0         1       1          PC 17599  71.2833
# 3    35.0         1       1            113803  53.1000
# 6    54.0         0       1             17463  51.8625
# 9    14.0         1       2            237736  30.0708
# 11   58.0         1       1            113783  26.5500
# ..    ...       ...     ...               ...      ...
# 880  25.0         1       2            230433  26.0000
# 883  28.0         0       2  C.A./SOTON 34068  10.5000
# 886  27.0         0       2            211536  13.0000
# 887  19.0         1       1            112053  30.0000
# 889  26.0         1       1            111369  30.0000
#
# [400 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 5:
# - Obten un DataFrame con los pasajeros de la clase 1 y 3, menores a 30 años.

# %%
df[(df['Pclass'].isin([1,3])) & (df['Age'] < 30)]
# Out:
#      PassengerId                                               Name     Sex  \
# 23            24                       Sloper, Mr. William Thompson    male
# 27            28                     Fortune, Mr. Charles Alexander    male
# 34            35                            Meyer, Mr. Edgar Joseph    male
# 83            84                            Carrau, Mr. Francisco M    male
# 88            89                         Fortune, Miss. Mabel Helen  female
# 97            98                    Greenfield, Mr. William Bertram    male
# 102          103                          White, Mr. Richard Frasar    male
# 118          119                           Baxter, Mr. Quigg Edmond    male
# 136          137                       Newsom, Miss. Helen Monypeny  female
# 139          140                                 Giglio, Mr. Victor    male
# 151          152                  Pears, Mrs. Thomas (Edith Wearne)  female
# 290          291                       Barber, Miss. Ellen "Nellie"  female
# 291          292            Bishop, Mrs. Dickinson H (Helen Walton)  female
# 297          298                       Allison, Miss. Helen Loraine  female
# 305          306                     Allison, Master. Hudson Trevor    male
# 307          308  Penasco y Castellana, Mrs. Victor de Satode (M...  female
# 310          311                     Hays, Miss. Margaret Bechstein  female
# 311          312                         Ryerson, Miss. Emily Borie  female
# 329          330                       Hippach, Miss. Jean Gertrude  female
# 336          337                          Pears, Mr. Thomas Clinton    male
# 341          342                     Fortune, Miss. Alice Elizabeth  female
# 356          357                        Bowerman, Miss. Elsie Edith  female
# 369          370                      Aubart, Mme. Leontine Pauline  female
# 370          371                        Harder, Mr. George Achilles    male
# 373          374                                Ringhini, Mr. Sante    male
# 377          378                          Widener, Mr. Harry Elkins    male
# 393          394                             Newell, Miss. Marjorie  female
# 430          431          Bjornstrom-Steffansson, Mr. Mauritz Hakan    male
# 435          436                          Carter, Miss. Lucile Polk  female
# 445          446                          Dodge, Master. Washington    male
# 484          485                            Bishop, Mr. Dickinson H    male
# 498          499    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 504          505                              Maioni, Miss. Roberta  female
# 505          506         Penasco y Castellana, Mr. Victor de Satode    male
# 539          540                 Frolicher, Miss. Hedwig Margaritha  female
# 550          551                        Thayer, Mr. John Borland Jr    male
# 585          586                                Taussig, Miss. Ruth  female
# 607          608                        Daniel, Mr. Robert Williams    male
# 627          628                      Longley, Miss. Gretchen Fiske  female
# 641          642                               Sagesser, Mlle. Emma  female
# 681          682                                 Hassab, Mr. Hammad    male
# 689          690                  Madill, Miss. Georgette Alexandra  female
# 700          701  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# 708          709                               Cleaver, Miss. Alice  female
# 710          711   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")  female
# 724          725                      Chambers, Mr. Norman Campbell    male
# 730          731                      Allen, Miss. Elisabeth Walton  female
# 742          743              Ryerson, Miss. Susan Parker "Suzette"  female
# 748          749                          Marvin, Mr. Daniel Warner    male
# 781          782          Dick, Mrs. Albert Adrian (Vera Gillespie)  female
# 782          783                             Long, Mr. Milton Clyde    male
# 802          803                Carter, Master. William Thornton II    male
# 853          854                          Lines, Miss. Mary Conover  female
# 887          888                       Graham, Miss. Margaret Edith  female
# 889          890                              Behr, Mr. Karl Howell    male
#
#        Age  Survived  Pclass    Ticket      Fare
# 23   28.00         1       1    113788   35.5000
# 23   28.0         1       1            113788  35.5000
# ..    ...       ...     ...               ...      ...
# 882  22.0         0       3              7552  10.5167
# 883  28.0         0       2  C.A./SOTON 34068  10.5000
# 884  25.0         0       3   SOTON/OQ 392076   7.0500
# 886  27.0         0       2            211536  13.0000
# 889  26.0         1       1            111369  30.0000
#
# [245 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 7:
# - Obten un DataFrame con los pasajeros menores a 25 años y mayores a 50 años.

# %%
df[ ~(df['Age'].between(25, 50)) ]
# Out:
#      PassengerId                                           Name     Sex   Age  \
# 0              1                        Braund, Mr. Owen Harris    male  22.0
# 5              6                               Moran, Mr. James    male   NaN
# 6              7                        McCarthy, Mr. Timothy J    male  54.0
# 7              8                 Palsson, Master. Gosta Leonard    male   2.0
# 9             10            Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ..           ...                                            ...     ...   ...
# 878          879                             Laleff, Mr. Kristo    male   NaN
# 879          880  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 882          883                   Dahlberg, Miss. Gerda Ulrika  female  22.0
# 887          888                   Graham, Miss. Margaret Edith  female  19.0
# 888          889       Johnston, Miss. Catherine Helen "Carrie"  female   NaN
#
#      Survived  Pclass      Ticket     Fare
# 0           0       3   A/5 21171   7.2500
# 5           0       3      330877   8.4583
# 6           0       1       17463  51.8625
# 7           0       3      349909  21.0750
# 9           1       2      237736  30.0708
# ..        ...     ...         ...      ...
# 878         0       3      349217   7.8958
# 879         1       1       11767  83.1583
# 882         0       3        7552  10.5167
# 887         1       1      112053  30.0000
# 888         0       3  W./C. 6607  23.4500
#
# [519 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 8:
# - Remplaza los valores de sexo, por M para male y F para female.

# %%
df['Sex'] = df['Sex'].replace({"male": "M", "female": "F"})

# %% [markdown]
# ### Ejercicio 9:
# - Convierte en mayusculas todos los nombres de los pasajeros.

# %%
df['Name'] = df['Name'].apply(lambda x: x.upper())

# %%
df
# Out:
#      PassengerId                                               Name Sex   Age  \
# 0              1                            BRAUND, MR. OWEN HARRIS   M  22.0
# 1              2  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...   F  38.0
# 2              3                             HEIKKINEN, MISS. LAINA   F  26.0
# 3              4       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)   F  35.0
# 4              5                           ALLEN, MR. WILLIAM HENRY   M  35.0
# ..           ...                                                ...  ..   ...
# 886          887                              MONTVILA, REV. JUOZAS   M  27.0
# 887          888                       GRAHAM, MISS. MARGARET EDITH   F  19.0
# 888          889           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"   F   NaN
# 889          890                              BEHR, MR. KARL HOWELL   M  26.0
# 890          891                                DOOLEY, MR. PATRICK   M  32.0
#
#      Survived  Pclass            Ticket     Fare
# 0           0       3         A/5 21171   7.2500
# 1           1       1          PC 17599  71.2833
# 2           1       3  STON/O2. 3101282   7.9250
# 3           1       1            113803  53.1000
# 4           0       3            373450   8.0500
# ..        ...     ...               ...      ...
# 886         0       2            211536  13.0000
# 887         1       1            112053  30.0000
# 888         0       3        W./C. 6607  23.4500
# 889         1       1            111369  30.0000
# 890         0       3            370376   7.7500
#
# [891 rows x 8 columns]

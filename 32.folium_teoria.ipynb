# %% [markdown]
# ## Folium
#
# ```python
# pip install folium
# ```
# *__QuickStart__: https://python-visualization.github.io/folium/quickstart.html*
#
# *__Documentacion__: https://python-visualization.github.io/folium/modules.html*
#
#
# **`Folium`** es una poderosa biblioteca de python que nos ayuda a crear varios tipos de mapas. El hecho de que los resultados de Folium sean interactivos hace que esta biblioteca sea muy útil para la construcción de paneles.
#
# La generación del mapa mundial es muy sencilla en **`folium`**. Simplemente crea un objeto **`folium.map()`** y luego lo visualiza. Lo atractivo de los mapas **`folium`** es que son interactivos, por lo que puede acercarse a cualquier región de interés a pesar del nivel de zoom inicial.

# %%
import numpy as np  
import pandas as pd

import folium

# %%
folium.__version__
# Out:
# '0.16.0'

# %%
# Crear el objeto mapa
world_map = folium.Map()

# Mostar el mapa
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad5e3d0f38ecf42d852e0e93f8b12b0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad5e3d0f38ecf42d852e0e93f8b12b0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad5e3d0f38ecf42d852e0e93f8b12b0d = L.map(
#                 &quot;map_ad5e3d0f38ecf42d852e0e93f8b12b0d&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_146d4c024ddacfe3c034378a5db23cac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_146d4c024ddacfe3c034378a5db23cac.addTo(map_ad5e3d0f38ecf42d852e0e93f8b12b0d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
type(world_map)
# Out:
# folium.folium.Map

# %% [markdown]
# Todas las ubicaciones en un mapa están definidas por sus respectivos valores **Latitud** y **Longitud**. Por lo tanto, se puede crear un mapa y pasar un centro de valores de Latitud y Longitud, por ejemplo [40.4637, -3.7492].
#
# También se puede definir el nivel de **zoom** inicial en esa ubicación cuando se representa el mapa. **Cuanto más alto sea el nivel de zoom, más se acercará el mapa al centro.**

# %%
# Creamos un mapa centrado en España con zoom igual a 6 
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 6)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8c844beffb7a6577f7b4037c2ddcc3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8c844beffb7a6577f7b4037c2ddcc3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8c844beffb7a6577f7b4037c2ddcc3b = L.map(
#                 &quot;map_d8c844beffb7a6577f7b4037c2ddcc3b&quot;,
#                 {
#                     center: [40.4637, -3.7492],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef5901daaec237e0d215c7615a41512c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef5901daaec237e0d215c7615a41512c.addTo(map_d8c844beffb7a6577f7b4037c2ddcc3b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Creamos un mapa centrado en España con zoom igual a 8
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 8)

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_012e7da83b20b2261979e90e6178bd9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_012e7da83b20b2261979e90e6178bd9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_012e7da83b20b2261979e90e6178bd9a = L.map(
#                 &quot;map_012e7da83b20b2261979e90e6178bd9a&quot;,
#                 {
#                     center: [40.4637, -3.7492],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0142831a4698da655bbc944dbe6be495 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0142831a4698da655bbc944dbe6be495.addTo(map_012e7da83b20b2261979e90e6178bd9a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Tipos de mapas:
#
# 1. **Stamen Toner Maps**: Estos son mapas en blanco y negro de alto contraste. Son perfecto para combinar datos y explorar ríos y zonas costeras.

# %%
# Stamen Toner Map
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 8, tiles = "Stamen Toner")

world_map
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Stamen Toner Map
# ----> 2 world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 8, tiles = "Stamen Toner")
#       4 world_map
#
# File c:\Users\fran\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\folium.py:308, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     306     self.add_child(tiles)
#     307 elif tiles:
# --> 308     tile_layer = TileLayer(
#     309         tiles=tiles, attr=attr, min_zoom=min_zoom, max_zoom=max_zoom
#     310     )
#     311     self.add_child(tile_layer, name=tile_layer.tile_name)
#
# File c:\Users\fran\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\raster_layers.py:140, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     138 self.tiles = tiles
#     139 if not attr:
# --> 140     raise ValueError("Custom tiles must have an attribution.")
#     142 self.options = parse_options(
#     143     min_zoom=min_zoom,
#     144     max_zoom=max_zoom,
#    (...)
#     152     **kwargs,
#     153 )
#
# ValueError: Custom tiles must have an attribution.

# %% [markdown]
# 2. **Stamen Terrain Maps**: Estos son mapas que presentan sombreado de colinas y colores de vegetación natural. Muestran el etiquetado avanzado y la generalización de líneas de carreteras de doble calzada.

# %%
# Stamen Terrain Map
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 8, tiles = "Stamen Terrain")

world_map
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Stamen Terrain Map
# ----> 2 world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 8, tiles = "Stamen Terrain")
#       4 world_map
#
# File c:\Users\fran\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\folium.py:308, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     306     self.add_child(tiles)
#     307 elif tiles:
# --> 308     tile_layer = TileLayer(
#     309         tiles=tiles, attr=attr, min_zoom=min_zoom, max_zoom=max_zoom
#     310     )
#     311     self.add_child(tile_layer, name=tile_layer.tile_name)
#
# File c:\Users\fran\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\raster_layers.py:140, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     138 self.tiles = tiles
#     139 if not attr:
# --> 140     raise ValueError("Custom tiles must have an attribution.")
#     142 self.options = parse_options(
#     143     min_zoom=min_zoom,
#     144     max_zoom=max_zoom,
#    (...)
#     152     **kwargs,
#     153 )
#
# ValueError: Custom tiles must have an attribution.

# %% [markdown]
# 3. **Stamen Watercolor**: Mapa representado con estilo de "acuarelas".

# %%
# Stamen Watercolor Map
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 4, tiles = "Stamen Watercolor")

world_map
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Stamen Watercolor Map
# ----> 2 world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 4, tiles = "Stamen Watercolor")
#       4 world_map
#
# File c:\Users\fran\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\folium.py:308, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     306     self.add_child(tiles)
#     307 elif tiles:
# --> 308     tile_layer = TileLayer(
#     309         tiles=tiles, attr=attr, min_zoom=min_zoom, max_zoom=max_zoom
#     310     )
#     311     self.add_child(tile_layer, name=tile_layer.tile_name)
#
# File c:\Users\fran\AppData\Local\Programs\Python\Python312\Lib\site-packages\folium\raster_layers.py:140, in TileLayer.__init__(self, tiles, min_zoom, max_zoom, max_native_zoom, attr, detect_retina, name, overlay, control, show, no_wrap, subdomains, tms, opacity, **kwargs)
#     138 self.tiles = tiles
#     139 if not attr:
# --> 140     raise ValueError("Custom tiles must have an attribution.")
#     142 self.options = parse_options(
#     143     min_zoom=min_zoom,
#     144     max_zoom=max_zoom,
#    (...)
#     152     **kwargs,
#     153 )
#
# ValueError: Custom tiles must have an attribution.

# %% [markdown]
# 4. **CartoDB Positron**: Mapa sin información relevante a escala de grises, diseñado para que la información representada en ella sea más llamativa.

# %%
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 6, tiles = "CartoDB Positron")

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9f852c039fa27fb6dc809fd758446c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9f852c039fa27fb6dc809fd758446c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9f852c039fa27fb6dc809fd758446c0 = L.map(
#                 &quot;map_d9f852c039fa27fb6dc809fd758446c0&quot;,
#                 {
#                     center: [40.4637, -3.7492],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f712b7030eb5a5c7045a779f24b0a0fe = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f712b7030eb5a5c7045a779f24b0a0fe.addTo(map_d9f852c039fa27fb6dc809fd758446c0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 5. **CartoDB Dark_Matter**: Mapa sin información relevante a escala de negros, diseñado para que la información representada en ella sea más llamativa.

# %%
world_map = folium.Map(location = [40.4637, -3.7492], zoom_start = 6, tiles = "CartoDB Dark_Matter")

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35aeecfd4bdedd35755cdd481099cdab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35aeecfd4bdedd35755cdd481099cdab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35aeecfd4bdedd35755cdd481099cdab = L.map(
#                 &quot;map_35aeecfd4bdedd35755cdd481099cdab&quot;,
#                 {
#                     center: [40.4637, -3.7492],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90dc5df9284b15429e80ac1945262d99 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_90dc5df9284b15429e80ac1945262d99.addTo(map_35aeecfd4bdedd35755cdd481099cdab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### "Estilos" en folium

# %%
# Se descarga un .csv con incidentes ocurridos en San Francisco

df_incidents = pd.read_csv("https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Police_Department_Incidents_-_Previous_Year__2016_.csv").head(10)

df_incidents
# Out:
#    IncidntNum        Category                                        Descript  \
# 0   120058272     WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272     WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263        WARRANTS                                  WARRANT ARREST
# 3   160013662    NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740    NON-CRIMINAL                                   LOST PROPERTY
# 5   160002869         ASSAULT                                         BATTERY
# 6   160003130  OTHER OFFENSES                                PAROLE VIOLATION
# 7   160003259    NON-CRIMINAL                                     FIRE REPORT
# 8   160003970        WARRANTS                                  WARRANT ARREST
# 9   160003641  MISSING PERSON                                    FOUND PERSON
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
# 5    Friday  01/01/2016 12:00:00 AM  21:35    NORTHERN            NONE
# 6  Saturday  01/02/2016 12:00:00 AM  00:04    SOUTHERN  ARREST, BOOKED
# 7  Saturday  01/02/2016 12:00:00 AM  01:02  TENDERLOIN            NONE
# 8  Saturday  01/02/2016 12:00:00 AM  12:21    SOUTHERN  ARREST, BOOKED
# 9    Friday  01/01/2016 12:00:00 AM  10:06     BAYVIEW            NONE
#
#                    Address           X          Y  \
# 0   800 Block of BRYANT ST -122.403405  37.775421
# 1   800 Block of BRYANT ST -122.403405  37.775421
# 2    KEITH ST / SHAFTER AV -122.388856  37.729981
# 3   JONES ST / OFARRELL ST -122.412971  37.785788
# 4     16TH ST / MISSION ST -122.419672  37.765050
# 5    1700 Block of BUSH ST -122.426077  37.788019
# 6      MARY ST / HOWARD ST -122.405721  37.780879
# 7     200 Block of EDDY ST -122.411778  37.783981
# 8        4TH ST / BERRY ST -122.393357  37.775788
# 9  100 Block of CAMERON WY -122.387182  37.720967
#
#                                 Location            PdId
# 0   (37.775420706711, -122.403404791479)  12005827212120
# 1   (37.775420706711, -122.403404791479)  12005827212168
# 2  (37.7299809672996, -122.388856204292)  14105926363010
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000
# 5   (37.788018555829, -122.426077177375)  16000286904134
# 6  (37.7808789360214, -122.405721454567)  16000313026150
# 7  (37.7839805592634, -122.411778295992)  16000325968000
# 8  (37.7757876218293, -122.393357241451)  16000397063010
# 9  (37.7209669615499, -122.387181635995)  16000364175000

# %% [markdown]
# Cada fila consta de 13 características:
#
# > 1. **IncidntNum**: Incident Number
# > 2. **Category**: Category of crime or incident
# > 3. **Descript**: Description of the crime or incident
# > 4. **DayOfWeek**: The day of week on which the incident occurred
# > 5. **Date**: The Date on which the incident occurred
# > 6. **Time**: The time of day on which the incident occurred
# > 7. **PdDistrict**: The police department district
# > 8. **Resolution**: The resolution of the crime in terms whether the perpetrator was arrested or not
# > 9. **Address**: The closest address to where the incident took place
# > 10. **X**: The longitude value of the crime location
# > 11. **Y**: The latitude value of the crime location
# > 12. **Location**: A tuple of the latitude and the longitude values
# > 13. **PdId**: The police department ID

# %%
df_incidents.shape
# Out:
# (10, 13)

# %%
# Vamos a truncar el DataFrame a 100 filas

limit = 100

df_incidents = df_incidents.iloc[0: limit, :]

df_incidents.shape
# Out:
# (10, 13)

# %%
df_incidents
# Out:
#    IncidntNum        Category                                        Descript  \
# 0   120058272     WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272     WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263        WARRANTS                                  WARRANT ARREST
# 3   160013662    NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740    NON-CRIMINAL                                   LOST PROPERTY
# 5   160002869         ASSAULT                                         BATTERY
# 6   160003130  OTHER OFFENSES                                PAROLE VIOLATION
# 7   160003259    NON-CRIMINAL                                     FIRE REPORT
# 8   160003970        WARRANTS                                  WARRANT ARREST
# 9   160003641  MISSING PERSON                                    FOUND PERSON
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
# 5    Friday  01/01/2016 12:00:00 AM  21:35    NORTHERN            NONE
# 6  Saturday  01/02/2016 12:00:00 AM  00:04    SOUTHERN  ARREST, BOOKED
# 7  Saturday  01/02/2016 12:00:00 AM  01:02  TENDERLOIN            NONE
# 8  Saturday  01/02/2016 12:00:00 AM  12:21    SOUTHERN  ARREST, BOOKED
# 9    Friday  01/01/2016 12:00:00 AM  10:06     BAYVIEW            NONE
#
#                    Address           X          Y  \
# 0   800 Block of BRYANT ST -122.403405  37.775421
# 1   800 Block of BRYANT ST -122.403405  37.775421
# 2    KEITH ST / SHAFTER AV -122.388856  37.729981
# 3   JONES ST / OFARRELL ST -122.412971  37.785788
# 4     16TH ST / MISSION ST -122.419672  37.765050
# 5    1700 Block of BUSH ST -122.426077  37.788019
# 6      MARY ST / HOWARD ST -122.405721  37.780879
# 7     200 Block of EDDY ST -122.411778  37.783981
# 8        4TH ST / BERRY ST -122.393357  37.775788
# 9  100 Block of CAMERON WY -122.387182  37.720967
#
#                                 Location            PdId
# 0   (37.775420706711, -122.403404791479)  12005827212120
# 1   (37.775420706711, -122.403404791479)  12005827212168
# 2  (37.7299809672996, -122.388856204292)  14105926363010
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000
# 5   (37.788018555829, -122.426077177375)  16000286904134
# 6  (37.7808789360214, -122.405721454567)  16000313026150
# 7  (37.7839805592634, -122.411778295992)  16000325968000
# 8  (37.7757876218293, -122.393357241451)  16000397063010
# 9  (37.7209669615499, -122.387181635995)  16000364175000

# %%
# Latitud y Longitud de San Francisco

latitude = 37.77
longitude = -122.42

# %%
# Inicializa el mapa ubicado en San Francisco
sf_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# Muestra el mapa
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14def785d5fec8664546d860758c8735 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14def785d5fec8664546d860758c8735&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14def785d5fec8664546d860758c8735 = L.map(
#                 &quot;map_14def785d5fec8664546d860758c8735&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2b5f42acf3a2d4a4ad0d9ab571ae3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1c2b5f42acf3a2d4a4ad0d9ab571ae3e.addTo(map_14def785d5fec8664546d860758c8735);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### folium.CircleMarker()

# %% [markdown]
# Ahora **superpongamos** las ubicaciones de los crímenes en el mapa. La forma de hacerlo en **`folium`** es crear un **`FeatureGroup()`** con sus propias características y estilos y luego agregarlo al mapa.

# %%
# Inicializamos un FeatureGroup() para los incidentes en el DataFrame
incidents = folium.map.FeatureGroup()

# Recorre los 100 crímenes y agrega a cada uno al FeatureGroup() de incidentes
# la columna Y y X son las coordenadas, latitud y longitud respectivamente

for lat, lng in zip(df_incidents["Y"], df_incidents["X"]): 
    
    incidents.add_child(folium.CircleMarker(location     = [lat, lng],
                                            radius       = 9,
                                            color        = "red",
                                            fill         = True,
                                            fill_color   = "yellow",
                                            fill_opacity = 0.6))


# Agrega incidentes al mapa
sf_map.add_child(incidents)

sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14def785d5fec8664546d860758c8735 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14def785d5fec8664546d860758c8735&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14def785d5fec8664546d860758c8735 = L.map(
#                 &quot;map_14def785d5fec8664546d860758c8735&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2b5f42acf3a2d4a4ad0d9ab571ae3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1c2b5f42acf3a2d4a4ad0d9ab571ae3e.addTo(map_14def785d5fec8664546d860758c8735);
#
#
#             tile_layer_1c2b5f42acf3a2d4a4ad0d9ab571ae3e.addTo(map_14def785d5fec8664546d860758c8735);
#
#
#             var feature_group_5b7fc89cd543914d482231ef87608b75 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_22a7ccadf946840d35b1849ca963b691 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b7fc89cd543914d482231ef87608b75);
#
#
#             var circle_marker_3efe3a4cbd7659f9f0ac6655c1573663 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b7fc89cd543914d482231ef87608b75);
#
#
#             var circle_marker_a1b10f131814f2f9e1776cc6ecfa95b3 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b7fc89cd543914d482231ef87608b75);
#
#
#             var circle_marker_0a83263f2ab47c459a3e41a2138c8deb = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b7fc89cd543914d482231ef87608b75);
#
#
#             var circle_marker_213a09e940689d634bc0c306eb2848b8 = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5b7fc89cd543914d482231ef87608b75);
#
#
#             var circle_marker_eb3f2dc02bbdcd12c0ccda03f4f2f4b0 = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot

# %% [markdown]
# ### folium.Marker()

# %%
# Volvemos a inicializar el mapa
sf_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# Inicializamos un FeatureGroup() para los incidentes en el DataFrame
incidents = folium.map.FeatureGroup()

# Recorre los 100 crímenes y agrega a cada uno al FeatureGroup() de incidentes
# La columna Y y X son las coordenadas, latitud y longitud respectivamente
# La columna "Category" es el tipo de incidente.

for lat, lng, label in zip(df_incidents["Y"], df_incidents["X"], df_incidents["Category"]):
    
    incidents.add_child(folium.Marker(location = [lat, lng],
                                      popup    = label))
    
# Agrega incidentes al map
sf_map.add_child(incidents)

sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12847828e89253288675cb5353c0c0b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12847828e89253288675cb5353c0c0b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12847828e89253288675cb5353c0c0b3 = L.map(
#                 &quot;map_12847828e89253288675cb5353c0c0b3&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba2d2f71f3faaed425ba2949b3e37dce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ba2d2f71f3faaed425ba2949b3e37dce.addTo(map_12847828e89253288675cb5353c0c0b3);
#
#
#             var feature_group_ed417c80e2b804162375d5cac1a7a9be = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_9145b3c3e4aaec3fa28778572ba8bce9 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(feature_group_ed417c80e2b804162375d5cac1a7a9be);
#
#
#         var popup_35d7a54770a53a1be7c0072b4f37408e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff4dd080968fc00c9b408a8bd06eef22 = $(`&lt;div id=&quot;html_ff4dd080968fc00c9b408a8bd06eef22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_35d7a54770a53a1be7c0072b4f37408e.setContent(html_ff4dd080968fc00c9b408a8bd06eef22);
#
#
#
#         marker_9145b3c3e4aaec3fa28778572ba8bce9.bindPopup(popup_35d7a54770a53a1be7c0072b4f37408e)
#         ;
#
#
#
#
#             var marker_58f810edeca2ef778b43d7ac0eee1575 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(feature_group_ed417c80e2b804162375d5cac1a7a9be);
#
#
#         var popup_565e9bfd47dc2b546845b1ef850e86d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bc6f4f662054dcad806224be15c4035b = $(`&lt;div id=&quot;html_bc6f4f662054dcad806224be15c4035b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_565e9bfd47dc2b546845b1ef850e86d8.setContent(html_bc6f4f662054dcad806224be15c4035b);
#
#
#
#         marker_58f810edeca2ef778b43d7ac0eee1575.bindPopup(popup_565e9bfd47dc2b546845b1ef850e86d8)
#         ;
#
#
#
#
#             var marker_8794973e2b0452021f74a444acc564ee = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(feature_group_ed417c80e2b804162375d5cac1a7a9be);
#
#
#         var popup_3783c167f9b2f192782897c221c70383 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df876e3174969f4388676f5df9015ebd = $(`&lt;div id=&quot;html_df876e3174969f4388676f5df9015ebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_3783c167f9b2f192782897c221c70383.setContent(html_df876e3174969f4388676f5df9015ebd);
#
#
#
#         marker_8794973e2b0452021f74a444acc564ee.bindPopup(popup_3783c167f9b2f192782897c221c70383)
#         ;
#
#
#
#
#             var marker_2a8cd1eb96a381811910ad46b0e58d6d = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(feature_group_ed417c80e2b804162375d5cac1a7a9be);
#
#
#         var popup_217e9a21bd854dd49e856ac01ed26c90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc6276ff27de2a138088ca686102d596 = $(`&lt;div id=&quot;html_dc6276ff27de2a138088ca686102d596&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_217e9a21bd854dd49e856ac01ed26c90.setContent(html_dc6276ff27de2a138088ca686102d596);
#
#
#
#         marker_2a8cd1eb96a381811910ad46b0e58d6d.bindPopup(popup_217e9a21bd854dd49e856ac01ed26c90)
#         ;
#
#
#
#
#             var marker_1bf1d1693bb4168b205749066fd43ff5 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(feature_group_ed417c80e2b804162375d5cac1a7a9be);
#
#
#         var popup_984a79f16965d36336bcc4768c55d564 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d4eef61ed5b20d6384adc15d33868cb = $(`&lt;div id=&quot;html_3d4eef61ed5b20d6384adc15d33868cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_984a79f16965d36336bcc4768c55d564.setContent(html_3d4eef61ed5b20d6384adc15d33868cb);
#
#
#
#         marker_1bf1d1693bb4168b205749066fd43ff5.bindPopup(popup_984a79f16965d36336bcc

# %% [markdown]
# ### Nube de marcadores
#
# **`folium.plugins.MarkerCluster()`**

# %%
from folium import plugins

# Volvemos a inicializar el mapa
sf_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# Creamos una instancia de un objeto de cluster (MarkerCluster())
# de marca para los incidentes en el marco de datos

incidents = plugins.MarkerCluster()

# Recorre los 100 crímenes y agrega a cada uno al FeatureGroup() de incidentes
# La columna Y y X son las coordenadas, latitud y longitud respectivamente
# La columna "Category" es el tipo de incidente.

for lat, lng, label, in zip(df_incidents["Y"], df_incidents["X"], df_incidents["Category"]):
    
    incidents.add_child(folium.Marker(location = [lat, lng],
                                      icon     = folium.Icon(icon           = "fa-birthday-cake",
                                                             icon_color     = "white",
                                                             color          = "green",
                                                             prefix         = "fa"),
                                      popup    = label))

    
# Agrega incidentes al map
sf_map.add_child(incidents)

sf_map


# Información de Iconos: https://www.adaweb.es/iconos-font-awesome-css-content-values/
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bc717980ae1e4b4d50c7af2f3e4e09e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bc717980ae1e4b4d50c7af2f3e4e09e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bc717980ae1e4b4d50c7af2f3e4e09e = L.map(
#                 &quot;map_8bc717980ae1e4b4d50c7af2f3e4e09e&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b6d3c28bdf32b186fd6eb68a35071cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9b6d3c28bdf32b186fd6eb68a35071cc.addTo(map_8bc717980ae1e4b4d50c7af2f3e4e09e);
#
#
#             var marker_cluster_b0611941c52af91a0c6577f2308a4664 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8df6bba3e1f77569c0ea9d7a7ded6609 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_b0611941c52af91a0c6577f2308a4664);
#
#
#             var icon_b294715efc286be640fed5c0cf37b464 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-birthday-cake&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8df6bba3e1f77569c0ea9d7a7ded6609.setIcon(icon_b294715efc286be640fed5c0cf37b464);
#
#
#         var popup_b8de1e229df7cf2eed972f3b30df93a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_557a75d61e038d7f98c923200e25d846 = $(`&lt;div id=&quot;html_557a75d61e038d7f98c923200e25d846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_b8de1e229df7cf2eed972f3b30df93a9.setContent(html_557a75d61e038d7f98c923200e25d846);
#
#
#
#         marker_8df6bba3e1f77569c0ea9d7a7ded6609.bindPopup(popup_b8de1e229df7cf2eed972f3b30df93a9)
#         ;
#
#
#
#
#             var marker_76b2fc2c15f2df2a19e2fd2d78aa1f95 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_b0611941c52af91a0c6577f2308a4664);
#
#
#             var icon_edd4547709dea1ef77c4c8dece915f81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-birthday-cake&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_76b2fc2c15f2df2a19e2fd2d78aa1f95.setIcon(icon_edd4547709dea1ef77c4c8dece915f81);
#
#
#         var popup_073404f84d81c77e190390e0fdf8eff8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a988fd8258b52eb7a1dc3cd4d4800ff3 = $(`&lt;div id=&quot;html_a988fd8258b52eb7a1dc3cd4d4800ff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_073404f84d81c77e190390e0fdf8eff8.setContent(html_a988fd8258b52eb7a1dc3cd4d4800ff3);
#
#
#
#         marker_76b2fc2c15f2df2a19e2fd2d78aa1f95.bindPopup(popup_073404f84d81c77e190390e0fdf8eff8)
#         ;
#
#
#
#
#             var marker_1cf6e8de32602ba81ede330b56184957 = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(marker_cluster_b0611941c52af91a0c6577f2308a4664);
#
#
#             var icon_bf8fadd64ef04301d350dd3ad1c2a53c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-birthday-cake&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1cf6e8de32602ba81ede330b56184957.setIcon(icon_bf8fadd64ef04301d350dd3ad1c2a53c);
#
#
#         var popup_11498a88bccc0564cf75920c87a12c68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5215a892a52d685b2d54b5e2a139da5 = $(`&lt;div id=&quot;html_c5215a892a52d685b2d54b5e2a139da5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_11498a88bccc0564cf75920c87a12c68

# %% [markdown]
# ## Choropleth Maps
#
# Un mapa **`Choropleth`** es un mapa temático en el que las áreas están sombreadas o modeladas en proporción a la medición de la variable estadística que se muestra en el mapa, como la densidad de población o el ingreso per cápita. El **`Choropleth`** map proporciona una manera fácil de visualizar cómo varía una medición en un área geográfica o muestra el nivel de variabilidad dentro de una región.
#
# Ahora, creemos nuestro propio mapa **`Choropleth`** del mundo que represente la inmigración de varios países a Canada.

# %%
canada = pd.read_excel(io = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx",
                       sheet_name = "Canada by Citizenship",
                       skiprows = range(20),
                       skipfooter = 2).head(10)

canada
# Out:
#          Type    Coverage               OdName  AREA  \
# 0  Immigrants  Foreigners          Afghanistan   935
# 1  Immigrants  Foreigners              Albania   908
# 2  Immigrants  Foreigners              Algeria   903
# 3  Immigrants  Foreigners       American Samoa   909
# 4  Immigrants  Foreigners              Andorra   908
# 5  Immigrants  Foreigners               Angola   903
# 6  Immigrants  Foreigners  Antigua and Barbuda   904
# 7  Immigrants  Foreigners            Argentina   904
# 8  Immigrants  Foreigners              Armenia   935
# 9  Immigrants  Foreigners            Australia   909
#
#                           AreaName   REG                    RegName  DEV  \
# 0                             Asia  5501              Southern Asia  902
# 1                           Europe   925            Southern Europe  901
# 2                           Africa   912            Northern Africa  902
# 3                          Oceania   957                  Polynesia  902
# 4                           Europe   925            Southern Europe  901
# 5                           Africa   911              Middle Africa  902
# 6  Latin America and the Caribbean   915                  Caribbean  902
# 7  Latin America and the Caribbean   931              South America  902
# 8                             Asia   922               Western Asia  902
# 9                          Oceania   927  Australia and New Zealand  901
#
#               DevName  1980  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0  Developing regions    16  ...  2978  3436  3009  2652  2111  1746  1758
# 1   Developed regions     1  ...  1450  1223   856   702   560   716   561
# 2  Developing regions    80  ...  3616  3626  4807  3623  4005  5393  4752
# 3  Developing regions     0  ...     0     0     1     0     0     0     0
# 4   Developed regions     0  ...     0     0     1     1     0     0     0
# 5  Developing regions     1  ...   268   295   184   106    76    62    61
# 6  Developing regions     0  ...    14    24    32    15    32    38    27
# 7  Developing regions   368  ...  1591  1153   847   620   540   467   459
# 8  Developing regions     0  ...   147   224   218   198   205   267   252
# 9   Developed regions   702  ...   930   909   875  1033  1018  1018   933
#
#    2011  2012  2013
# 0  2203  2635  2004
# 1   539   620   603
# 2  4325  3774  4331
# 3     0     0     0
# 4     0     1     1
# 5    39    70    45
# 6    37    51    25
# 7   278   263   282
# 8   236   258   207
# 9   851   982  1121
#
# [10 rows x 43 columns]

# %%
canada.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 canada.shape
#
# NameError: name 'canada' is not defined

# %%
canada
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 canada
#
# NameError: name 'canada' is not defined

# %%
# Limpiamos el Dataframe para remover columnas no necesarias: 
canada.drop(["AREA", "REG", "DEV", "Type", "Coverage"], axis = 1, inplace = True)

# Cambiamos el nombre a las columnas para que tengan más sentido

canada.rename(columns = {"OdName" : "Country",
                         "AreaName" : "Continent",
                         "RegName" : "Region"}, inplace = True)

# Para tener consistencia, cambiamos todas las etiquetas de columnas a tipo string
canada.columns = list(map(str, canada.columns))

# Agregamos la columna total 
canada["Total"] = canada[[str(x) for x in range(1980, 2014)]].sum(axis = 1)

years = list(map(str, range(1980, 2014)))

canada.shape

# %%
canada.head(3)

# %% [markdown]
# Para crear un mapa **`Choropleth`**, necesitamos un archivo **`GeoJSON`** que defina las áreas / límites del estado, condado o país en el que estamos interesados. En nuestro caso, dado que estamos tratando de crear un mapa mundial, quiere un **`GeoJSON`** que defina los límites de todos los países del mundo. Vamos a llamarlo **`world_countries.json`**
#
# Ahora que tenemos el archivo **`GeoJSON`**, creemos un mapa mundial, centrado alrededor de los valores **[0, 0]** latitud y longitud, con un nivel de zoom inicial de 2.

# %%
world_geo = "data/world_countries.json" # Archivo GeoJSON

# Crea un mapa mundial 
world_map = folium.Map(location = [0, 0], zoom_start = 2)

world_map

# %% [markdown]
# Y ahora para crear un mapa **`Choropleth`**, utilizaremos la función **`folium.Choropleth()`** con los siguientes parámetros principales:
#
# 1. **`geo_data`**, que es el archivo **`GeoJSON`**.
#
#
# 2. **`data`**, que es el **`DataFrame`** que contiene los datos.
#
#
# 3. **`columns`**, que representan las columnas en el **`DataFrame`** que se utilizarán para crear el mapa **`Choropleth`**.
#
#
# 4. **`key_on`**, que es la clave o variable en el archivo **`GeoJSON`** que contiene el nombre de la variable de interés. Para determinar eso, deberá abrir el archivo **`GeoJSON`** utilizando cualquier editor de texto y anotar el nombre de la clave o variable que contiene el nombre de los países, ya que los países son nuestra variable de interés. En este caso, name es la clave en el archivo **`GeoJSON`** que contiene el nombre de los países. Tenga en cuenta que esta clave es sensible a mayúsculas y minúsculas, por lo que debe pasar exactamente como existe en el archivo **`GeoJSON`**.

# %%
folium.Choropleth(geo_data = world_geo,
                  data     = canada,
                  columns  = ["Country", "Total"],
                  key_on   = "feature.properties.name").add_to(world_map)

world_map

# %%
world_map = folium.Map(location = [0, 0], zoom_start = 2)

folium.Choropleth(geo_data     = "data/world_countries.json",
                  data         = canada,
                  columns      = ["Country", "Total"],
                  key_on       = "feature.properties.name",
                  fill_color   = "Blues_r", 
                  fill_opacity = 0.7, 
                  line_opacity = 0.2,
                  legend_name  = "Immigration to Canada").add_to(world_map)

world_map

# %%
world_map.save("mapa_choropleth.html")

# %%
################################################################################################################################

# %%
canada["Country"].replace("Venezuela (Bolivarian Republic of)", "Venezuela", inplace = True)

# %%
paises_df = canada["Country"].to_list()

# %%
import json

with open("Data/world_countries.json", mode = "r") as file:
    
    datos = json.load(file)

# %%
paises_json = [x["properties"]["name"] for x in datos["features"]]

# %%
coincidencias = list()
no_coincidencias = list()

for pais in paises_df:
    
    if pais in paises_json:
        
        coincidencias.append(pais)

    else:
        
        no_coincidencias.append(pais)

# %%
canada[canada["Country"] == "American Samoa"]

# %%
paises_json

# %%
no_coincidencias
